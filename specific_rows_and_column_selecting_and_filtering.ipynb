# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data_sample.csv", encoding="latin1")

# %%
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
specific_column =  df['ORDERNUMBER']

# %%
print(specific_column)
# Out:
# 0       10107
# 1       10121
# 2       10134
# 3       10145
# 4       10159
#         ...
# 2818    10350
# 2819    10373
# 2820    10386
# 2821    10397
# 2822    10414
# Name: ORDERNUMBER, Length: 2823, dtype: int64

# %%
multiple_specific_column = df[['ORDERNUMBER' , 'QUANTITYORDERED', 'SALES']]

# %%
print(multiple_specific_column)
# Out:
#       ORDERNUMBER  QUANTITYORDERED    SALES
# 0           10107               30  2871.00
# 1           10121               34  2765.90
# 2           10134               41  3884.34
# 3           10145               45  3746.70
# 4           10159               49  5205.27
# ...           ...              ...      ...
# 2818        10350               20  2244.40
# 2819        10373               29  3978.51
# 2820        10386               43  5417.57
# 2821        10397               34  2116.16
# 2822        10414               47  3079.44
#
# [2823 rows x 3 columns]

# %%
#Filtering rows

# %%
single_row = df [df['QUANTITYORDERED']> 45]

# %%
print(single_row)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49     100.00               14  5205.27
# 7           10188               48     100.00                1  5512.32
# 18          10318               46      94.74                1  4358.04
# 25          10417               66     100.00                2  7516.08
# 35          10206               47     100.00                6  9064.89
# ...           ...              ...        ...              ...      ...
# 2790        10352               49      52.64                4  2579.36
# 2793        10386               50      87.15               16  4357.50
# 2798        10117               50      43.68                2  2184.00
# 2801        10153               50      60.06                4  3003.00
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
multiple_row_condition =  df[(df['QUANTITYORDERED']> 60) & (df['SALES']>9000.00)]

# %%
print(multiple_row_condition)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 104         10403               66     100.00                9  11886.60
# 131         10400               64     100.00                9   9661.44
# 418         10405               97      93.28                5   9048.16
# 598         10407               76     100.00                2  14082.80
# 1188        10406               65     100.00                1  10468.90
# 1995        10405               76     100.00                3  11739.70
# 1996        10419               70     100.00                8   9240.00
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 104    4/8/2005 0:00   Shipped       2         4     2005  ...
# 131    4/1/2005 0:00   Shipped       2         4     2005  ...
# 418   4/14/2005 0:00   Shipped       2         4     2005  ...
# 598   4/22/2005 0:00   On Hold       2         4     2005  ...
# 1188  4/15/2005 0:00  Disputed       2         4     2005  ...
# ...

# %%
another_multiple_row_condition = df[(df['PRICEEACH']>99.00) & (df['SALES']>9000.00)]

# %%
print(another_multiple_row_condition)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 30          10150               45      100.0                8  10993.50
# 35          10206               47      100.0                6   9064.89
# 43          10304               47      100.0                6  10172.70
# 44          10312               48      100.0                3  11623.70
# 53          10424               50      100.0                6  12001.00
# 81          10120               46      100.0                2   9264.86
# 90          10223               49      100.0                3   9774.03
# 104         10403               66      100.0                9  11886.60
# 105         10417               56      100.0                4   9218.16
# 131         10400               64      100.0                9   9661.44
# 164         10147               48      100.0                7   9245.76
# 174         10266               44      100.0               14   9160.36
# ...
